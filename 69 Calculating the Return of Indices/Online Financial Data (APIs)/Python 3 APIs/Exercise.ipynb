# %%
import pandas_datareader as wb
import pandas as pd
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC','^IXIC','^GDAXI']

ticker=tickers[0]
ticker
# Out:
# '^GSPC'

# %%
wb.DataReader(ticker,data_source='yahoo',start='1997-1-1')
# Out:
#                    High          Low         Open        Close      Volume  \
# Date
# 1997-01-02   742.809998   729.549988   740.739990   737.010010   463230000
# 1997-01-03   748.239990   737.010010   737.010010   748.030029   452970000
# 1997-01-06   753.309998   743.820007   748.030029   747.650024   531350000
# 1997-01-07   753.260010   742.179993   747.650024   753.229980   538220000
# 1997-01-08   755.719971   747.710022   753.229980   748.409973   557510000
# ...                 ...          ...          ...          ...         ...
# 2021-02-04  3872.419922  3836.659912  3836.659912  3871.739990  4856670000
# 2021-02-05  3894.560059  3874.929932  3878.300049  3886.830078  4838580000
# 2021-02-08  3915.770020  3892.590088  3892.590088  3915.590088  4635030000
# 2021-02-09  3918.350098  3902.639893  3910.489990  3911.229980  4554610000
# 2021-02-10  3931.500000  3884.939941  3920.780029  3906.840088  1164403417
#
#               Adj Close
# Date
# 1997-01-02   737.010010
# 1997-01-03   748.030029
# 1997-01-06   747.650024
# 1997-01-07   753.229980
# 1997-01-08   748.409973
# ...                 ...
# 2021-02-04  3871.739990
# 2021-02-05  3886.830078
# 2021-02-08  3915.590088
# 2021-02-09  3911.229980
# 2021-02-10  3906.840088
#
# [6068 rows x 6 columns]

# %%
ind_data=pd.DataFrame()
for t in tickers:
    ind_data[t]=wb.DataReader(t,data_source='yahoo',start='1997-1-1')["Adj Close"]

# %%
((ind_data/ind_data.iloc[0])*100).plot(figsize=(15,6))

plt.show()

# %%
ind_return=(ind_data/ind_data.shift(1))-1
ind_return.tail(4)
# Out:
#                ^GSPC     ^IXIC    ^GDAXI
# Date
# 2021-02-05  0.003897  0.005702 -0.000254
# 2021-02-08  0.007399  0.009479  0.000227
# 2021-02-09 -0.001114  0.001434 -0.003422
# 2021-02-10 -0.001122 -0.002468 -0.005626

# %%
annual_ind_return=ind_return.mean()*250
annual_ind_return
# Out:
# ^GSPC     0.088124
# ^IXIC     0.130190
# ^GDAXI    0.078895
# dtype: float64

# %%
tickers=['PG','^GSPC','^DJI']
data_2=pd.DataFrame()
for t in tickers:
    data_2[t]=wb.DataReader(t,data_source='yahoo',start='1997-1-1')['Adj Close']
data_2.tail(4)
# Out:
#                     PG        ^GSPC          ^DJI
# Date
# 2021-02-05  129.570007  3886.830078  31148.240234
# 2021-02-08  129.169998  3915.590088  31385.759766
# 2021-02-09  128.669998  3911.229980  31375.830078
# 2021-02-10  128.089798  3906.100098  31390.769531

# %%
((data_2/data_2.iloc[0])*100).plot(figsize=(15,6))
plt.show()
