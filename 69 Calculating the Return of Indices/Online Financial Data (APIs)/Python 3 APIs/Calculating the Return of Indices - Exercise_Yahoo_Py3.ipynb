# %% [markdown]
# ## Calculating the Return of Indices

# %% [markdown]
# Consider three famous American market indices – Dow Jones, S&P 500, and the Nasdaq for the period of 1st of January 2000 until today.

# %%
import pandas_datareader as wb
import pandas as pd
import matplotlib.pyplot as plt

tickers=['^DJI','^GSPC','^IXIC']
data=pd.DataFrame()
for t in tickers:
    data[t]=wb.DataReader(t,data_source='yahoo',start='2000-1-1')['Adj Close']

# %% [markdown]
# Normalize the data to 100 and plot the results on a graph.

# %%
((data/data.iloc[0])*100).plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# How would you explain the common and the different parts of the behavior of the three indices?

# %% [markdown]
# *****

# %% [markdown]
# Obtain the simple returns of the indices.

# %%
returns=round((data/data.shift(1)-1)*100,3)
returns
# Out:
#              ^DJI  ^GSPC  ^IXIC
# Date
# 2000-01-03    NaN    NaN    NaN
# 2000-01-04 -3.166 -3.834 -5.554
# 2000-01-05  1.134  0.192 -0.619
# 2000-01-06  1.174  0.096 -3.879
# 2000-01-07  2.393  2.709  4.172
# ...           ...    ...    ...
# 2021-02-04  1.081  1.085  1.228
# 2021-02-05  0.297  0.390  0.570
# 2021-02-08  0.763  0.740  0.948
# 2021-02-09 -0.032 -0.111  0.143
# 2021-02-10  0.198 -0.034 -0.251
#
# [5311 rows x 3 columns]

# %% [markdown]
# Estimate the average annual return of each index.

# %%
returns.mean()*250
# Out:
# ^DJI     6.609699
# ^GSPC    6.616196
# ^IXIC    8.935546
# dtype: float64
